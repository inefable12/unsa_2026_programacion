# %% [markdown]
# # **Tarea 1**

# %% [markdown]
# **Ejercicio 1:** Realice un programa que pida al usuario un número entero y muestre por pantalla un triángulo rectángulo con la altura del número introducido.
# ```
# Output:
# Introduce un número: 5
# x
# xx
# xxx
# xxxx
# xxxxx
# ```

# %% [markdown]
# **Ejercicio 2:** Realice un programa usando for y while el cual pida el primer número e imprima los 10 primeros números .

# %% [markdown]
# **Ejercicio 3:** Basado en el ejercicio anterior, ahora ingresa la razón (cada cuanto se debe aumentar), e imprima los 10 primeros números

# %% [markdown]
# **Ejercicio 4:** Realice un programa en el  cual se ingrese un número, e indique si es múltiplo de 3.

# %% [markdown]
# **Ejercicio 5:** Realice un programa el cuál lea números enteros de teclado, hasta que el usuario ingrese el 0. (WHILE)

# %% [markdown]
# **Ejercicio 6:** Realice un programa que pida al usuario un número entero positivo y muestre por pantalla todos los números impares desde 1 hasta ese número. (FOR)

# %% [markdown]
# **Ejercicio 7:** Realice un programa el cuál lea un número entero positivo desde teclado e imprimir la suma de los dígitos que lo componen. (WHILE)

# %% [markdown]
# **Ejercicio 8:** Escribir un programa que pregunte el nombre de un producto, su precio y un número de unidades y sea almacenado en una lista. Muestre por pantalla los datos solicitados. Ejm:
# ```
# Ingrese el producto: pan
# Ingrese el precio: 0.3
# Ingrese la cantidad: 15
# Se ha comprado 15 unidades de pan, pagando 4.5 soles.
# ```

# %% [markdown]
# **Ejercicio 9:** Escribir una función encontrar() que reciba por parámetro dos cadenas: palabra y una cadena (ingresadas por el usuario). Retornar True si la cadena se encuentra dentro de la palabra y False si no se encuentra (No usar find()).`
#
# ```
# Output:
# encontrar(“abbbcccc”, “aa”)
# Debe retornar  False.
# encontrar(“revista”, “vista”)
# Debe retornar  True.
# ```

# %% [markdown]
# **Ejercicio 10:** Escribir una función elimina_duplicados de una lista L y retorna una nueva lista sin los elementos duplicados. No utilice operador in o not in.
# ````
# Output:
# elimina_duplicados([500,100,200,300,200,100,600,400,800,400,500,900])
# Debe retornar: [500, 100, 200, 300, 600, 400, 800, 900]
# ````

# %% [markdown]
# **Ejercicio 11:** Generar una matriz cuadrada (núm entre 1 y 15). Imprimir los elementos de la matriz de forma invertida, el último elemento ingresado debe ser el primero en imprimirse.

# %% [markdown]
# **Ejercicio 12:** Usando la matriz anterior sumar el valor de filas y de columnas.

# %% [markdown]
# **Ejercicio 13:** Usando la matriz anterior, pedir al usuario que ingrese un número entre el 1 y el 10, e indique si el elemento está en la lista, y si es afirmativa la respuesta indicar cuantas veces se repite.
