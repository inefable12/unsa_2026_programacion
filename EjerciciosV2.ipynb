# %% [markdown]
# # **Ejercicios 2**

# %% [markdown]
# **Ejercicio 1:** Escribir un programa que indique si la palabra es palindromo o no (una palabra que se escribe igual al derecho y al revés) por ejemplo rotor es palindromo, motor no lo es.

# %% [markdown]
# **Ejercicio 2:** Escribir un programa que pida al usuario un número entero positivo y muestre por pantalla la cuenta atrás desde ese número hasta cero separados por comas.

# %% [markdown]
# **Ejercicio 3:** Escribir un programa que pida al usuario tres números, el  inicio, el fin y el paso, de tal forma que comience a contar respetando el inicio, fin y paso. Ejemplo
# ```
# Inicio = 4
# Fin = 20
# Paso = 5
# Salida: 4,  9, 14, 19
# ```

# %% [markdown]
# **Ejercicio 4:** Escribir un programa que invierta  un número ingresado por teclado.
# ````
# Numero = 12345
# Salida: 54321

# %% [markdown]
# **Ejercicio 5:** Dado un entero que representa la altura, escribir un programa que guarde en una cadena que contenga el siguiente patrón ( Resolver usando el bucle for anidado)
# `````
# altura = 5
# 1
# 12
# 123
# 1234
# 12345

# %% [markdown]
# **Ejercicio 6:** Escribir un programa que pida al usuario un número entero y muestre por pantalla un triángulo rectángulo como el de más abajo, de altura el número introducido.
# ````
# Altura = 5
# 0
# 0 2
# 0 2 4
# 0 2 4 6
# 0 2 4 6 8

# %% [markdown]
# **Ejercicio 7:** Escribir un programa que pida al usuario un número entero y muestre por pantalla un triángulo rectángulo como el de más abajo, de altura el número introducido.
# ````
# Altura = 5
# 1
# 3 1
# 5 3 1
# 7 5 3 1
# 9 7 5 3 1

# %% [markdown]
# **Ejercicio 8:** Dado un símbolo y una altura, escribir un programa que imprima el siguiente patrón.
# ````
# Simbolo = *
# Altura = 5
#           *
#          ***
#         *****
#        *******
#       *********

# %% [markdown]
# **Ejercicio 9:** Escribir un programa en el que se pregunte al usuario por una frase y una letra, y muestre por pantalla el número de veces que aparece la letra en la frase.

# %% [markdown]
# **Ejercicio 10:** Escribir un programa en el que se pregunte al usuario por una frase  y una letra, y muestre por pantalla la letra reemplazada por el
# ````
# símbolo *:
# Frase= Hola como estas
# Letra = a
# Salida=Hol* como est*s
